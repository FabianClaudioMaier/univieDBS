# %% [markdown]
# # Demo Notebook

# %% [markdown]
# A notebook describing the basics for connecting via python to oracle.

# %% [markdown]
# **First, ensure that you installed cx_Oracle with:**
#
# `python -m pip install cx_Oracle --upgrade`

# %% [markdown]
# ## Get the libraries

# %%
import cx_Oracle
import random
from datetime import datetime, timedelta

# %% [markdown]
# ## Get Basic Client

# %% [markdown]
# see here: https://www.oracle.com/database/technologies/instant-client/winx64-64-downloads.html

# %%
cx_Oracle.init_oracle_client('/opt/oracle/instantclient_23_3') #add here the path to the instantclient

# %% [markdown]
# ## Set the credentials

# %%
username="a11907564"  #db user name
password="dbs24" #db password 
con_string="oracle19.cs.univie.ac.at:1521/orclcdb"

# %% [markdown]
# ## Connect

# %%
#consider to use with in order to avoid open connections
connection = cx_Oracle.connect(user=username, password=password,
                               dsn=con_string,
                               encoding="UTF-8")

# %% [markdown]
# Check if connection is now up!

# %%
#create a table
curs=connection.cursor()
create_stat="create table myTestTable(myId INTEGER)" #just an example: always use a PK
curs.execute(create_stat)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[57], line 4
#       2 curs=connection.cursor()
#       3 create_stat="create table myTestTable(myId INTEGER)" #just an example: always use a PK
# ----> 4 curs.execute(create_stat)
#       5 connection.commit()
#
# DatabaseError: ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/

# %%
#insert into
myIdValue=4
create_stat="insert into myTestTable (myId) VALUES (:myIdValue)"
curs.execute(create_stat,myIdValue=myIdValue)
connection.commit()

# %%
#select
curs.execute("select * from myTestTable")
res = curs.fetchall()

# %%
str(res)  #result
# Out:
# '[(4,), (4,), (4,)]'

# %%
[x[0] for x in res]
# Out:
# [4, 4, 4]

# %% [markdown]
# # Read from CSV

# %%
import pandas as pd

# %%
example_data=pd.read_csv("ExampleData.csv",sep=";")

# %%
example_data.head()
# Out:
#    Id   Name
# 0   9    Ann
# 1  10    Bob
# 2  11  Carol

# %%
#create a table
create_stat="create table myTestTable2(myId INTEGER,myName VARCHAR(30))" #just an example: always use a PK
curs.execute(create_stat)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[65], line 3
#       1 #create a table
#       2 create_stat="create table myTestTable2(myId INTEGER,myName VARCHAR(30))" #just an example: always use a PK
# ----> 3 curs.execute(create_stat)
#       4 connection.commit()
#
# DatabaseError: ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/

# %%
def add_tuple(m_tuple):
    create_stat="insert into myTestTable2 (myId,myName) VALUES (:myId,:myName)"
    curs.execute(create_stat,myId=m_tuple.Id,myName=m_tuple.Name)
    connection.commit()

# %%
example_data.apply(lambda x: add_tuple(x),axis=1)  #use for instead of apply if that is easier for your!
print("done with inserting....")
# Out:
# done with inserting....

# %%
curs.execute("select * from myTestTable2")
res = curs.fetchall()
res
# Out:
# [(9, 'Ann'),
#  (10, 'Bob'),
#  (11, 'Carol'),
#  (9, 'Ann'),
#  (10, 'Bob'),
#  (11, 'Carol'),
#  (9, 'Ann'),
#  (10, 'Bob'),
#  (11, 'Carol')]

# %% [markdown]
# # DB Triggers
#
# execute the Triggers from Aufgabe 3-2.
#
# Can be found in db_triggers.sql

# %%
import os


# Path to the SQL file
sql_file_path = 'db_trigger.sql'

try:
    # Read the SQL file
    with open(sql_file_path, 'r') as file:
        sql_commands = file.read()

    # Execute the SQL commands
    for command in sql_commands.split(';'):  # Split commands if needed
        command = command.strip()
        if command:  # Ignore empty commands
            curs.execute(command)
            print(f"Executed: {command}")

    # Commit changes
    connection.commit()
    print("All commands executed successfully.")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: name 'curs' is not defined

# %% [markdown]
# # Aufgabe 3-3

# %% [markdown]
# 1. Verbindung zur Datenbank

# %%
import cx_Oracle

# first wie want to establish a connection to the database (just in case this hasn't allready been done)

connection = cx_Oracle.connect(user=username, password=password,
                               dsn=con_string,
                               encoding="UTF-8")
curs = connection.cursor()

print("Verbindung erfolgreich!")



#then we want to make sure that the physical layout of the DB is established. The according Requests can be found in the File db_triggers.sql

# Path to the SQL file
sql_file_path = 'db_trigger.sql' 

try:
    # Read the SQL file
    with open(sql_file_path, 'r') as file:
        sql_commands = file.read()
        print(file)

    # Execute the SQL commands
    for command in sql_commands.split(';'):  # Split commands if needed
        command = command.strip()
        if command:  # Ignore empty commands
            try:
                curs.execute(command)
                print(f"Executed: {command}")
            except Exception as e:
                print(f"Error : {e}")

    # Commit changes
    connection.commit()
    print("All commands executed successfully.")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Verbindung erfolgreich!
# <_io.TextIOWrapper name='db_trigger.sql' mode='r' encoding='utf-8'>
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Error : ORA-00955: name is already used by an existing object
# Help: https://docs.oracle.com/error-help/db/ora-00955/
# Executed: -- Create auto-increment trigger
# CREATE OR REPLACE TRIGGER auto_increment_Kunden_Anbieter
# BEFORE INSERT ON Kunden_Anbieter
# FOR EACH ROW
# BEGIN
#   SELECT Kunden_Anbieter_Seq.NEXTVAL INTO :NEW.ID FROM dual
# Error : ORA-00900: invalid SQL statement
# Help: https://docs.oracle.com/error-help/db/ora-00900/
# Executed: -- Create business logic trigger
# CREATE OR REPLACE TRIGGER update_vehicle_status
# AFTER INSERT ON Reservierungen
# FOR EACH ROW
# BEGIN
#   UPDATE Fahrzeuge
#   SET Status = 'Reserved'
#   WHERE FahrzeugID = :NEW.FahrzeugID
# Error : ORA-00900: invalid SQL statement
# Help: https://docs.oracle.com/error-help/db/ora-00900/
# Error : ORA-04098: trigger 'A11907564.AUTO_INCREMENT_KUNDEN_ANBIETER' is invalid and failed re-validation
# Help: https://docs.oracle.com/error-help/db/ora-04098/
# Error : ORA-04098: trigger 'A11907564.AUTO_INCREMENT_KUNDEN_ANBIETER' is invalid and failed re-validation
# Help: https://docs.oracle.com/error-help/db/ora-04098/
# Error : ORA-04098: trigger 'A11907564.UPDATE_VEHICLE_STATUS' is invalid and failed re-validation
# Help: https://docs.oracle.com/error-help/db/ora-04098/
# All commands executed successfully.

# %%
sql_commands = [
    """
    CREATE OR REPLACE TRIGGER auto_increment_Kunden_Anbieter
    BEFORE INSERT ON Kunden_Anbieter
    FOR EACH ROW
    BEGIN
      SELECT Kunden_Anbieter_Seq.NEXTVAL INTO :NEW.ID FROM dual;
    END;
    """,
    """
    CREATE OR REPLACE TRIGGER update_vehicle_status
    AFTER INSERT ON Reservierungen
    FOR EACH ROW
    BEGIN
      UPDATE Fahrzeuge
      SET Status = 'Reserved'
      WHERE FahrzeugID = :NEW.FahrzeugID;
    END;
    """
]

# Execute each command
try:
    for command in sql_commands:
        curs.execute(command)
        print("Executed SQL command successfully.")
    connection.commit()
    print("All commands executed and committed successfully.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Executed SQL command successfully.
# Executed SQL command successfully.
# All commands executed and committed successfully.

# %% [markdown]
# 2. Generierung von Testdaten

# %%
# Kunden-Tabelle mit 100000 Einträgen befüllen - 100000 für Punkt 4 (Indexierung)

for i in range(1, 100001):
    kunden_id = i
    name = f'Kunde_{i}'
    adresse = f'Straße {random.randint(1, 100)}, Stadt {random.randint(1, 10)}'
    telefonnummer = f'01234567{random.randint(100, 999)}'
    email = f'kunde_{i}@example.com'
    try:
        curs.execute("""
            INSERT INTO Kunden (KundenID, Name, Adresse, Telefonnummer, Email)
            VALUES (:1, :2, :3, :4, :5)
        """, (kunden_id, name, adresse, telefonnummer, email))
    except Exception as e:
        print(f"Error: {e}")

connection.commit()
print("Kunden-Daten erfolgreich eingefügt!")
# Out:
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# ...
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116313) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/

# %%
# Fahrzeuge-Tabelle mit 500 Einträgen
for i in range(1, 501):
    fahrzeug_id = i
    kennzeichen = f'ABC-{i:04d}'
    modell = random.choice(['SUV', 'Kleinwagen', 'Limousine'])
    hersteller = random.choice(['Hersteller A', 'Hersteller B'])
    baujahr = random.randint(2000, 2023)
    status = random.choice(['verfügbar', 'vermietet', 'in Wartung'])
    try:
        curs.execute("""
            INSERT INTO Fahrzeuge (FahrzeugID, Kennzeichen, Modell, Hersteller, Baujahr, Status)
            VALUES (:1, :2, :3, :4, :5, :6)
        """, (fahrzeug_id, kennzeichen, modell, hersteller, baujahr, status))
    except Exception as e:
        print(f"Error: {e}")

connection.commit()
print("Fahrzeug-Daten erfolgreich eingefügt!")
# Out:
# Fahrzeug-Daten erfolgreich eingefügt!

# %%
# Reservierungen-Tabelle mit 10.000 Einträgen
for i in range(1, 10001):
    reservierungs_id = i
    kunden_id = random.randint(1, 1000)
    fahrzeug_id = random.randint(1, 500)
    startdatum = f'2025-01-{random.randint(1, 28)}'
    enddatum = f'2025-01-{random.randint(29, 31)}'
    kosten = round(random.uniform(50, 500), 2)
    try:
        curs.execute("""
            INSERT INTO Reservierungen (ReservierungsID, KundenID, FahrzeugID, Startdatum, Enddatum, Kosten)
            VALUES (:1, :2, :3, TO_DATE(:4, 'YYYY-MM-DD'), TO_DATE(:5, 'YYYY-MM-DD'), :6)
        """, (reservierungs_id, kunden_id, fahrzeug_id, startdatum, enddatum, kosten))
    except Exception as e:
        print(f"Error: {e}")
    
connection.commit()
print("Reservierungs-Daten erfolgreich eingefügt!")
# Out:
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# ...
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Error: ORA-00001: unique constraint (A11907564.SYS_C001116316) violated
# Help: https://docs.oracle.com/error-help/db/ora-00001/
# Reservierungs-Daten erfolgreich eingefügt!

# %%
# Fill the Anbieter table
print("Populating Anbieter table...")
for i in range(1, 101):  # 100 entries for Anbieter
    anbieter_id = i
    name = f"Anbieter_{i}"
    adresse = f"Straße {random.randint(1, 50)}, Stadt {random.randint(1, 10)}"
    telefonnummer = f"01234567{random.randint(100, 999)}"
    email = f"anbieter_{i}@example.com"
    try:
        curs.execute("""
            INSERT INTO Anbieter (AnbieterID, Name, Adresse, Telefonnummer, Email)
            VALUES (:1, :2, :3, :4, :5)
        """, (anbieter_id, name, adresse, telefonnummer, email))
    except Exception as e:
        print(f"Error inserting into Anbieter: {e}")

connection.commit()
print("Anbieter table populated successfully!")

# %%
# Fill the Zusatzleistungen table
print("Populating Zusatzleistungen table...")
for i in range(1, 501):  # 500 entries for Zusatzleistungen
    leistungs_id = i
    reservierungs_id = random.randint(1, 10000)  # Assuming 10,000 reservations exist
    beschreibung = random.choice(["Zusatzversicherung", "Kindersitz", "Navigation"])
    kosten = round(random.uniform(5, 50), 2)
    try:
        curs.execute("""
            INSERT INTO Zusatzleistungen (LeistungsID, ReservierungsID, Beschreibung, Kosten)
            VALUES (:1, :2, :3, :4)
        """, (leistungs_id, reservierungs_id, beschreibung, kosten))
    except Exception as e:
        print(f"Error inserting into Zusatzleistungen: {e}")

connection.commit()
print("Zusatzleistungen table populated successfully!")

# %%
# Fill the Kunden_Anbieter table
print("Populating Kunden_Anbieter table...")
for i in range(1, 1001):  # 1,000 entries for Kunden_Anbieter
    id_val = i
    kunden_id = random.randint(1, 1000)  # Assuming 1,000 customers exist
    anbieter_id = random.randint(1, 100)  # Assuming 100 providers exist
    try:
        curs.execute("""
            INSERT INTO Kunden_Anbieter (ID, KundenID, AnbieterID)
            VALUES (:1, :2, :3)
        """, (id_val, kunden_id, anbieter_id))
    except Exception as e:
        print(f"Error inserting into Kunden_Anbieter: {e}")

connection.commit()
print("Kunden_Anbieter table populated successfully!")

# %%
print("Populating Transaktionen table...")

# Assume 10,000 reservations exist, so we'll create 10,000 transactions
for i in range(1, 10001):
    transaktions_id = i
    reservierungs_id = random.randint(1, 10000)  # Assuming 10,000 reservations
    betrag = round(random.uniform(50, 500), 2)  # Random amount between 50 and 500
    zahlungsweise = random.choice(['Kreditkarte', 'Bar', 'Überweisung'])  # Random payment method
    zahlungsdatum = (datetime.now() - timedelta(days=random.randint(1, 365))).strftime('%Y-%m-%d')  # Random date within the last year

    try:
        # Insert into the Transaktionen table
        curs.execute("""
            INSERT INTO Transaktionen (TransaktionsID, ReservierungsID, Betrag, Zahlungsweise, Zahlungsdatum)
            VALUES (:1, :2, :3, :4, TO_DATE(:5, 'YYYY-MM-DD'))
        """, (transaktions_id, reservierungs_id, betrag, zahlungsweise, zahlungsdatum))
    except Exception as e:
        print(f"Error inserting into Transaktionen: {e}")

# Commit the transactions to the database
connection.commit()
print("Transaktionen table populated successfully!")

# %% [markdown]
# 3. Sinnvolle Querries

# %% [markdown]
# Query 1: Durchschnittliche Kosten pro Fahrzeugmodell

# %%
query1 = """
SELECT Modell, AVG(Kosten) AS Durchschnittskosten
FROM Fahrzeuge
JOIN Reservierungen ON Fahrzeuge.FahrzeugID = Reservierungen.FahrzeugID
GROUP BY Modell
HAVING AVG(Kosten) > 200
"""
curs.execute(query1)
for row in curs.fetchall():
    print(f"Output: {row}")
# Out:
# Output: ('Kleinwagen', 274.40583735909826)
# Output: ('Limousine', 273.5024405594406)
# Output: ('SUV', 275.52748096074987)

# %% [markdown]
# Query 2: Top-Kunden mit den meisten Reservierungen

# %%
query2 = """
SELECT Kunden.Name, COUNT(Reservierungen.ReservierungsID) AS AnzahlReservierungen
FROM Kunden
JOIN Reservierungen ON Kunden.KundenID = Reservierungen.KundenID
GROUP BY Kunden.Name
ORDER BY AnzahlReservierungen DESC
FETCH FIRST 10 ROWS ONLY
"""
curs.execute(query2)
for row in curs.fetchall():
    print(row)
# Out:
# ('Kunde_264', 20)
# ('Kunde_801', 20)
# ('Kunde_58', 19)
# ('Kunde_385', 19)
# ('Kunde_862', 19)
# ('Kunde_614', 19)
# ('Kunde_254', 19)
# ('Kunde_93', 18)
# ('Kunde_682', 18)
# ('Kunde_737', 18)

# %% [markdown]
# Query 3: Fahrzeuge mit aktuellen Reservierungen

# %%
query3 = """
SELECT Fahrzeuge.FahrzeugID, Fahrzeuge.Kennzeichen, Reservierungen.Startdatum, Reservierungen.Enddatum
FROM Fahrzeuge
JOIN Reservierungen ON Fahrzeuge.FahrzeugID = Reservierungen.FahrzeugID
WHERE Reservierungen.Startdatum <= SYSDATE AND Reservierungen.Enddatum >= SYSDATE
"""
curs.execute(query3)
for row in curs.fetchall():
    print(row)
# Out:
# (116, 'ABC-0116', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (421, 'ABC-0421', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (455, 'ABC-0455', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (303, 'ABC-0303', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (2, 'ABC-0002', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (428, 'ABC-0428', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (49, 'ABC-0049', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (489, 'ABC-0489', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (478, 'ABC-0478', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (144, 'ABC-0144', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (165, 'ABC-0165', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (122, 'ABC-0122', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (93, 'ABC-0093', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (248, 'ABC-0248', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (186, 'ABC-0186', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (52, 'ABC-0052', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (143, 'ABC-0143', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (61, 'ABC-0061', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (288, 'ABC-0288', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (473, 'ABC-0473', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (491, 'ABC-0491', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (53, 'ABC-0053', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (92, 'ABC-0092', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (383, 'ABC-0383', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (205, 'ABC-0205', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (446, 'ABC-0446', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (430, 'ABC-0430', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (351, 'ABC-0351', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (419, 'ABC-0419', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (476, 'ABC-0476', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (276, 'ABC-0276', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (283, 'ABC-0283', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (158, 'ABC-0158', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (440, 'ABC-0440', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (74, 'ABC-0074', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (112, 'ABC-0112', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (231, 'ABC-0231', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (395, 'ABC-0395', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (498, 'ABC-0498', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (53, 'ABC-0053', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (321, 'ABC-0321', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (3, 'ABC-0003', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (260, 'ABC-0260', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (302, 'ABC-0302', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (91, 'ABC-0091', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (161, 'ABC-0161', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (225, 'ABC-0225', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (491, 'ABC-0491', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (402, 'ABC-0402', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (452, 'ABC-0452', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (275, 'ABC-0275', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (474, 'ABC-0474', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (480, 'ABC-0480', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (101, 'ABC-0101', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (441, 'ABC-0441', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (246, 'ABC-0246', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (219, 'ABC-0219', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (217, 'ABC-0217', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (196, 'ABC-0196', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (209, 'ABC-0209', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (112, 'ABC-0112', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (270, 'ABC-0270', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (41, 'ABC-0041', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (6, 'ABC-0006', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (303, 'ABC-0303', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (410, 'ABC-0410', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (305, 'ABC-0305', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (312, 'ABC-0312', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (244, 'ABC-0244', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (34, 'ABC-0034', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (384, 'ABC-0384', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (281, 'ABC-0281', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (341, 'ABC-0341', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (263, 'ABC-0263', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (11, 'ABC-0011', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (451, 'ABC-0451', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (239, 'ABC-0239', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (465, 'ABC-0465', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (317, 'ABC-0317', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (471, 'ABC-0471', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (309, 'ABC-0309', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (84, 'ABC-0084', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (341, 'ABC-0341', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (363, 'ABC-0363', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (160, 'ABC-0160', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (140, 'ABC-0140', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (255, 'ABC-0255', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (71, 'ABC-0071', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (2, 'ABC-0002', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (405, 'ABC-0405', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (349, 'ABC-0349', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (483, 'ABC-0483', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (43, 'ABC-0043', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (474, 'ABC-0474', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (356, 'ABC-0356', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (10, 'ABC-0010', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (264, 'ABC-0264', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (264, 'ABC-0264', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (252, 'ABC-0252', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (377, 'ABC-0377', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (162, 'ABC-0162', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (442, 'ABC-0442', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (138, 'ABC-0138', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (28, 'ABC-0028', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (299, 'ABC-0299', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (381, 'ABC-0381', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (279, 'ABC-0279', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (124, 'ABC-0124', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (363, 'ABC-0363', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (298, 'ABC-0298', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (251, 'ABC-0251', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (405, 'ABC-0405', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (261, 'ABC-0261', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (125, 'ABC-0125', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (210, 'ABC-0210', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (98, 'ABC-0098', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (114, 'ABC-0114', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (298, 'ABC-0298', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (107, 'ABC-0107', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (250, 'ABC-0250', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (210, 'ABC-0210', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (437, 'ABC-0437', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (403, 'ABC-0403', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (446, 'ABC-0446', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (329, 'ABC-0329', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (66, 'ABC-0066', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (476, 'ABC-0476', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (209, 'ABC-0209', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (17, 'ABC-0017', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (181, 'ABC-0181', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (321, 'ABC-0321', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (318, 'ABC-0318', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (490, 'ABC-0490', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (376, 'ABC-0376', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (300, 'ABC-0300', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (133, 'ABC-0133', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (373, 'ABC-0373', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (82, 'ABC-0082', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (344, 'ABC-0344', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (371, 'ABC-0371', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (94, 'ABC-0094', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (75, 'ABC-0075', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (67, 'ABC-0067', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (269, 'ABC-0269', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (153, 'ABC-0153', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (42, 'ABC-0042', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (255, 'ABC-0255', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (489, 'ABC-0489', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (258, 'ABC-0258', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (131, 'ABC-0131', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (345, 'ABC-0345', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (350, 'ABC-0350', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (191, 'ABC-0191', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (36, 'ABC-0036', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (362, 'ABC-0362', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (329, 'ABC-0329', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (364, 'ABC-0364', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (432, 'ABC-0432', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (155, 'ABC-0155', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (24, 'ABC-0024', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (14, 'ABC-0014', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (143, 'ABC-0143', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (420, 'ABC-0420', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (35, 'ABC-0035', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (75, 'ABC-0075', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (70, 'ABC-0070', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (320, 'ABC-0320', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (81, 'ABC-0081', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (266, 'ABC-0266', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (257, 'ABC-0257', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (468, 'ABC-0468', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (38, 'ABC-0038', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (470, 'ABC-0470', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (463, 'ABC-0463', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (447, 'ABC-0447', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (176, 'ABC-0176', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (366, 'ABC-0366', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (103, 'ABC-0103', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (304, 'ABC-0304', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (411, 'ABC-0411', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (154, 'ABC-0154', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (251, 'ABC-0251', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (48, 'ABC-0048', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (282, 'ABC-0282', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (417, 'ABC-0417', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (56, 'ABC-0056', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (157, 'ABC-0157', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (449, 'ABC-0449', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (462, 'ABC-0462', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (498, 'ABC-0498', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (216, 'ABC-0216', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (300, 'ABC-0300', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (487, 'ABC-0487', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (205, 'ABC-0205', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (93, 'ABC-0093', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (98, 'ABC-0098', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (32, 'ABC-0032', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (9, 'ABC-0009', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (140, 'ABC-0140', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (180, 'ABC-0180', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (301, 'ABC-0301', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (407, 'ABC-0407', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (105, 'ABC-0105', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (22, 'ABC-0022', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (417, 'ABC-0417', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (459, 'ABC-0459', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (460, 'ABC-0460', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (46, 'ABC-0046', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (309, 'ABC-0309', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (19, 'ABC-0019', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (243, 'ABC-0243', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (112, 'ABC-0112', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (69, 'ABC-0069', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (274, 'ABC-0274', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (305, 'ABC-0305', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (362, 'ABC-0362', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (484, 'ABC-0484', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (114, 'ABC-0114', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (497, 'ABC-0497', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (241, 'ABC-0241', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (272, 'ABC-0272', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (2, 'ABC-0002', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (345, 'ABC-0345', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (5, 'ABC-0005', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (493, 'ABC-0493', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (326, 'ABC-0326', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (332, 'ABC-0332', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (379, 'ABC-0379', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (415, 'ABC-0415', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (439, 'ABC-0439', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (88, 'ABC-0088', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (165, 'ABC-0165', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (47, 'ABC-0047', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (245, 'ABC-0245', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (197, 'ABC-0197', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (395, 'ABC-0395', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (128, 'ABC-0128', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (226, 'ABC-0226', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (61, 'ABC-0061', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (466, 'ABC-0466', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (454, 'ABC-0454', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (165, 'ABC-0165', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (404, 'ABC-0404', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (151, 'ABC-0151', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (283, 'ABC-0283', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (296, 'ABC-0296', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (316, 'ABC-0316', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (280, 'ABC-0280', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (164, 'ABC-0164', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (43, 'ABC-0043', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (260, 'ABC-0260', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (110, 'ABC-0110', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (128, 'ABC-0128', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (77, 'ABC-0077', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (351, 'ABC-0351', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (483, 'ABC-0483', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (190, 'ABC-0190', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (362, 'ABC-0362', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (413, 'ABC-0413', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (65, 'ABC-0065', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (119, 'ABC-0119', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (317, 'ABC-0317', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (327, 'ABC-0327', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (295, 'ABC-0295', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (357, 'ABC-0357', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (121, 'ABC-0121', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (210, 'ABC-0210', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (261, 'ABC-0261', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (218, 'ABC-0218', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (39, 'ABC-0039', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (339, 'ABC-0339', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (367, 'ABC-0367', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (356, 'ABC-0356', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (81, 'ABC-0081', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (43, 'ABC-0043', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (231, 'ABC-0231', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (33, 'ABC-0033', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (127, 'ABC-0127', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (53, 'ABC-0053', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (192, 'ABC-0192', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (86, 'ABC-0086', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (265, 'ABC-0265', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (261, 'ABC-0261', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (388, 'ABC-0388', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (20, 'ABC-0020', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (436, 'ABC-0436', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (493, 'ABC-0493', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (281, 'ABC-0281', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (327, 'ABC-0327', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (375, 'ABC-0375', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (89, 'ABC-0089', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (164, 'ABC-0164', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (303, 'ABC-0303', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (385, 'ABC-0385', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (218, 'ABC-0218', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (282, 'ABC-0282', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (73, 'ABC-0073', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (318, 'ABC-0318', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (209, 'ABC-0209', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (52, 'ABC-0052', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (14, 'ABC-0014', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (95, 'ABC-0095', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (331, 'ABC-0331', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (485, 'ABC-0485', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (37, 'ABC-0037', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (449, 'ABC-0449', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (207, 'ABC-0207', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (60, 'ABC-0060', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (499, 'ABC-0499', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (56, 'ABC-0056', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (363, 'ABC-0363', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (496, 'ABC-0496', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (1, 'ABC-0001', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (291, 'ABC-0291', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (275, 'ABC-0275', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (256, 'ABC-0256', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (193, 'ABC-0193', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (21, 'ABC-0021', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (207, 'ABC-0207', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (355, 'ABC-0355', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (291, 'ABC-0291', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (57, 'ABC-0057', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (153, 'ABC-0153', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (149, 'ABC-0149', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (132, 'ABC-0132', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (440, 'ABC-0440', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (271, 'ABC-0271', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (366, 'ABC-0366', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (63, 'ABC-0063', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (236, 'ABC-0236', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (3, 'ABC-0003', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (290, 'ABC-0290', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (446, 'ABC-0446', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (355, 'ABC-0355', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (296, 'ABC-0296', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (126, 'ABC-0126', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (285, 'ABC-0285', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (186, 'ABC-0186', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (213, 'ABC-0213', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (182, 'ABC-0182', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (331, 'ABC-0331', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (228, 'ABC-0228', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (44, 'ABC-0044', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (130, 'ABC-0130', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (283, 'ABC-0283', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (52, 'ABC-0052', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (348, 'ABC-0348', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (196, 'ABC-0196', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (113, 'ABC-0113', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (454, 'ABC-0454', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (220, 'ABC-0220', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (320, 'ABC-0320', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (473, 'ABC-0473', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (134, 'ABC-0134', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (228, 'ABC-0228', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (185, 'ABC-0185', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (117, 'ABC-0117', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (60, 'ABC-0060', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (124, 'ABC-0124', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (3, 'ABC-0003', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (340, 'ABC-0340', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (78, 'ABC-0078', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (488, 'ABC-0488', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (496, 'ABC-0496', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (441, 'ABC-0441', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (124, 'ABC-0124', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (184, 'ABC-0184', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (411, 'ABC-0411', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (164, 'ABC-0164', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (111, 'ABC-0111', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (47, 'ABC-0047', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (176, 'ABC-0176', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (174, 'ABC-0174', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (416, 'ABC-0416', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (478, 'ABC-0478', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (402, 'ABC-0402', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (339, 'ABC-0339', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (153, 'ABC-0153', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (288, 'ABC-0288', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (345, 'ABC-0345', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (227, 'ABC-0227', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (130, 'ABC-0130', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (411, 'ABC-0411', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (43, 'ABC-0043', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (50, 'ABC-0050', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (298, 'ABC-0298', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (360, 'ABC-0360', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (213, 'ABC-0213', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (91, 'ABC-0091', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (254, 'ABC-0254', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (140, 'ABC-0140', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (311, 'ABC-0311', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (212, 'ABC-0212', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (453, 'ABC-0453', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (312, 'ABC-0312', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (365, 'ABC-0365', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (332, 'ABC-0332', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (333, 'ABC-0333', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (313, 'ABC-0313', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (184, 'ABC-0184', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (205, 'ABC-0205', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (30, 'ABC-0030', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (23, 'ABC-0023', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (213, 'ABC-0213', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (168, 'ABC-0168', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (498, 'ABC-0498', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (28, 'ABC-0028', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (168, 'ABC-0168', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (114, 'ABC-0114', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (277, 'ABC-0277', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (445, 'ABC-0445', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (175, 'ABC-0175', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (403, 'ABC-0403', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (118, 'ABC-0118', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (239, 'ABC-0239', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (86, 'ABC-0086', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (34, 'ABC-0034', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (117, 'ABC-0117', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (29, 'ABC-0029', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (456, 'ABC-0456', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (218, 'ABC-0218', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (272, 'ABC-0272', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (373, 'ABC-0373', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (160, 'ABC-0160', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (209, 'ABC-0209', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (312, 'ABC-0312', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (40, 'ABC-0040', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (419, 'ABC-0419', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (313, 'ABC-0313', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (7, 'ABC-0007', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (363, 'ABC-0363', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (366, 'ABC-0366', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (166, 'ABC-0166', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (9, 'ABC-0009', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (318, 'ABC-0318', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (210, 'ABC-0210', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (460, 'ABC-0460', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (315, 'ABC-0315', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (225, 'ABC-0225', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (89, 'ABC-0089', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (362, 'ABC-0362', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (359, 'ABC-0359', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (410, 'ABC-0410', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (269, 'ABC-0269', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (344, 'ABC-0344', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (73, 'ABC-0073', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (122, 'ABC-0122', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (45, 'ABC-0045', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (439, 'ABC-0439', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (27, 'ABC-0027', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (233, 'ABC-0233', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (165, 'ABC-0165', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (464, 'ABC-0464', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (301, 'ABC-0301', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (434, 'ABC-0434', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (311, 'ABC-0311', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (121, 'ABC-0121', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (247, 'ABC-0247', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (31, 'ABC-0031', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (24, 'ABC-0024', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (98, 'ABC-0098', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (333, 'ABC-0333', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (136, 'ABC-0136', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (372, 'ABC-0372', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (262, 'ABC-0262', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (101, 'ABC-0101', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (335, 'ABC-0335', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (461, 'ABC-0461', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (406, 'ABC-0406', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (224, 'ABC-0224', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (146, 'ABC-0146', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (82, 'ABC-0082', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (80, 'ABC-0080', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (29, 'ABC-0029', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (329, 'ABC-0329', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (124, 'ABC-0124', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (3, 'ABC-0003', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (162, 'ABC-0162', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (382, 'ABC-0382', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (216, 'ABC-0216', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (468, 'ABC-0468', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (424, 'ABC-0424', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (416, 'ABC-0416', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (495, 'ABC-0495', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (347, 'ABC-0347', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (477, 'ABC-0477', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (66, 'ABC-0066', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (172, 'ABC-0172', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (237, 'ABC-0237', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (411, 'ABC-0411', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (218, 'ABC-0218', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (264, 'ABC-0264', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (402, 'ABC-0402', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (201, 'ABC-0201', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (462, 'ABC-0462', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (461, 'ABC-0461', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (466, 'ABC-0466', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (36, 'ABC-0036', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (41, 'ABC-0041', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (91, 'ABC-0091', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (335, 'ABC-0335', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (241, 'ABC-0241', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (1, 'ABC-0001', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (400, 'ABC-0400', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (143, 'ABC-0143', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# ...
# (328, 'ABC-0328', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (145, 'ABC-0145', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (240, 'ABC-0240', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (48, 'ABC-0048', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (94, 'ABC-0094', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (388, 'ABC-0388', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (94, 'ABC-0094', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (78, 'ABC-0078', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (306, 'ABC-0306', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (65, 'ABC-0065', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (2, 'ABC-0002', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (243, 'ABC-0243', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (23, 'ABC-0023', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (441, 'ABC-0441', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (108, 'ABC-0108', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (442, 'ABC-0442', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (428, 'ABC-0428', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (112, 'ABC-0112', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (211, 'ABC-0211', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (450, 'ABC-0450', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (273, 'ABC-0273', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (92, 'ABC-0092', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (304, 'ABC-0304', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (75, 'ABC-0075', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (54, 'ABC-0054', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (355, 'ABC-0355', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (236, 'ABC-0236', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (9, 'ABC-0009', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (252, 'ABC-0252', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (75, 'ABC-0075', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (152, 'ABC-0152', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (342, 'ABC-0342', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (213, 'ABC-0213', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (40, 'ABC-0040', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (170, 'ABC-0170', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (379, 'ABC-0379', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (197, 'ABC-0197', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (221, 'ABC-0221', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (65, 'ABC-0065', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (194, 'ABC-0194', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (391, 'ABC-0391', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (407, 'ABC-0407', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (60, 'ABC-0060', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (41, 'ABC-0041', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (210, 'ABC-0210', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (446, 'ABC-0446', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (383, 'ABC-0383', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (37, 'ABC-0037', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (375, 'ABC-0375', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (382, 'ABC-0382', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (275, 'ABC-0275', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (53, 'ABC-0053', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (458, 'ABC-0458', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (427, 'ABC-0427', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (465, 'ABC-0465', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (287, 'ABC-0287', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (5, 'ABC-0005', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (226, 'ABC-0226', datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (476, 'ABC-0476', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (142, 'ABC-0142', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (340, 'ABC-0340', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (64, 'ABC-0064', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (190, 'ABC-0190', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (26, 'ABC-0026', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (252, 'ABC-0252', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (228, 'ABC-0228', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (180, 'ABC-0180', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (426, 'ABC-0426', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (242, 'ABC-0242', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (90, 'ABC-0090', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (403, 'ABC-0403', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (263, 'ABC-0263', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (21, 'ABC-0021', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (300, 'ABC-0300', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (38, 'ABC-0038', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (107, 'ABC-0107', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (461, 'ABC-0461', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (61, 'ABC-0061', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (497, 'ABC-0497', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (168, 'ABC-0168', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (453, 'ABC-0453', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (474, 'ABC-0474', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (108, 'ABC-0108', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (261, 'ABC-0261', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (199, 'ABC-0199', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (491, 'ABC-0491', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (302, 'ABC-0302', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (154, 'ABC-0154', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (33, 'ABC-0033', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (32, 'ABC-0032', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (105, 'ABC-0105', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (98, 'ABC-0098', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (343, 'ABC-0343', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (290, 'ABC-0290', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (214, 'ABC-0214', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (311, 'ABC-0311', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (236, 'ABC-0236', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (436, 'ABC-0436', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (480, 'ABC-0480', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (359, 'ABC-0359', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (109, 'ABC-0109', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (215, 'ABC-0215', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (222, 'ABC-0222', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (374, 'ABC-0374', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (27, 'ABC-0027', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (249, 'ABC-0249', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (14, 'ABC-0014', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (44, 'ABC-0044', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (446, 'ABC-0446', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (164, 'ABC-0164', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (75, 'ABC-0075', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (202, 'ABC-0202', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (361, 'ABC-0361', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (422, 'ABC-0422', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (297, 'ABC-0297', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (71, 'ABC-0071', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (81, 'ABC-0081', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (349, 'ABC-0349', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (344, 'ABC-0344', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (81, 'ABC-0081', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (474, 'ABC-0474', datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (54, 'ABC-0054', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (277, 'ABC-0277', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (386, 'ABC-0386', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (496, 'ABC-0496', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (422, 'ABC-0422', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (224, 'ABC-0224', datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (376, 'ABC-0376', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (243, 'ABC-0243', datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (255, 'ABC-0255', datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (373, 'ABC-0373', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (486, 'ABC-0486', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (25, 'ABC-0025', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (265, 'ABC-0265', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (40, 'ABC-0040', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (451, 'ABC-0451', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (201, 'ABC-0201', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (122, 'ABC-0122', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (70, 'ABC-0070', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (363, 'ABC-0363', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (74, 'ABC-0074', datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (322, 'ABC-0322', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (359, 'ABC-0359', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (166, 'ABC-0166', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (251, 'ABC-0251', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (103, 'ABC-0103', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (108, 'ABC-0108', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (356, 'ABC-0356', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (188, 'ABC-0188', datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (134, 'ABC-0134', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (267, 'ABC-0267', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (238, 'ABC-0238', datetime.datetime(2025, 1, 2, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (59, 'ABC-0059', datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (226, 'ABC-0226', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (196, 'ABC-0196', datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (489, 'ABC-0489', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (161, 'ABC-0161', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (251, 'ABC-0251', datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (366, 'ABC-0366', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (103, 'ABC-0103', datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (464, 'ABC-0464', datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (477, 'ABC-0477', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (287, 'ABC-0287', datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (264, 'ABC-0264', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (269, 'ABC-0269', datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (320, 'ABC-0320', datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (407, 'ABC-0407', datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 29, 0, 0))
# (115, 'ABC-0115', datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 31, 0, 0))
# (258, 'ABC-0258', datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))
# (278, 'ABC-0278', datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 30, 0, 0))

# %% [markdown]
# 4. Neue Safe Procedure für das Updaten von Anbieter-Einträgen

# %%
procedure_code = """
CREATE OR REPLACE PROCEDURE UpdateAnbieterEmail (
    p_AnbieterID IN NUMBER,
    p_NewEmail IN VARCHAR2
) AS
BEGIN
    UPDATE Anbieter
    SET Email = p_NewEmail
    WHERE AnbieterID = p_AnbieterID;

    IF SQL%ROWCOUNT = 0 THEN
        RAISE_APPLICATION_ERROR(-20001, 'AnbieterID not found.');
    END IF;
END;
"""

try:
    # Execute the procedure creation
    curs.execute(procedure_code)
    print("Procedure 'UpdateAnbieterEmail' created successfully.")
except Exception as e:
    print(f"Error creating procedure: {e}")
# Out:
# Procedure 'UpdateAnbieterEmail' created successfully.

# %%
try:
    # Call the UpdateAnbieterEmail procedure
    curs.callproc('UpdateAnbieterEmail', [1, 'new_email@example.com'])
    print("Anbieter email updated successfully.")
except Exception as e:
    print(f"Error: {e}")

connection.commit()

curs.execute("SELECT * FROM Anbieter WHERE AnbieterID = 1")
print(curs.fetchall())
# Out:
# Anbieter email updated successfully.
# [(1, 'Anbieter_1', 'Straße 35, Stadt 10', '01234567888', 'new_email@example.com')]

# %% [markdown]
# 5. Neue Delete Procedure um Zusatzleistungen zu löschen

# %%
procedure_code = """
CREATE OR REPLACE PROCEDURE DeleteZusatzleistungen (
    p_ReservierungsID IN NUMBER,
    p_MaxKosten IN NUMBER
) AS
BEGIN
    DELETE FROM Zusatzleistungen
    WHERE ReservierungsID = p_ReservierungsID AND Kosten <= p_MaxKosten;

    IF SQL%ROWCOUNT = 0 THEN
        RAISE_APPLICATION_ERROR(-20002, 'No records found for the given parameters.');
    END IF;
END;
"""

try:
    # Execute the procedure creation
    curs.execute(procedure_code)
    print("Procedure 'DeleteZusatzleistungen' created successfully.")
except Exception as e:
    print(f"Error creating procedure: {e}")
# Out:
# Procedure 'DeleteZusatzleistungen' created successfully.

# %%
try:
    # Call the DeleteZusatzleistungen procedure
    curs.callproc('DeleteZusatzleistungen', [5940, 100])  # Example: ReservierungsID=10, MaxKosten=30
    print("Zusatzleistungen deleted successfully.")
except Exception as e:
    print(f"Error: {e}")

connection.commit()

curs.execute("SELECT * FROM Zusatzleistungen WHERE ReservierungsID = 10")
print(curs.fetchall())
# Out:
# Zusatzleistungen deleted successfully.
# []

# %% [markdown]
# 6. Indexierung anhand der Kunden Tabelle

# %%
try:
    # Execute the EXPLAIN PLAN query
    curs.execute("""
        EXPLAIN PLAN FOR
        SELECT * FROM Kunden WHERE email = 'kunde_1000@example.com'
    """)
    # Fetch the plan results
    curs.execute("SELECT * FROM TABLE(DBMS_XPLAN.DISPLAY())")
    plan = curs.fetchall()
    print("Execution plan without index:")
    for row in plan:
        print(row)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Execution plan without index:
# ('Plan hash value: 2881942826',)
# (' ',)
# ('----------------------------------------------------------------------------',)
# ('| Id  | Operation         | Name   | Rows  | Bytes | Cost (%CPU)| Time     |',)
# ('----------------------------------------------------------------------------',)
# ('|   0 | SELECT STATEMENT  |        |     1 |    68 |     5   (0)| 00:00:01 |',)
# ('|*  1 |  TABLE ACCESS FULL| KUNDEN |     1 |    68 |     5   (0)| 00:00:01 |',)
# ('----------------------------------------------------------------------------',)
# (' ',)
# ('Predicate Information (identified by operation id):',)
# ('---------------------------------------------------',)
# (' ',)
# ('   1 - filter("EMAIL"=\'kunde_1000@example.com\')',)

# %%
try:
    # Create an index on the 'email' column
    curs.execute("CREATE INDEX idx_email ON Kunden (email)")
    connection.commit()
    print("Index created successfully.")
except Exception as e:
    print(f"Error creating index: {e}")
# Out:
# Index created successfully.

# %%
try:
    # Execute the EXPLAIN PLAN query after adding the index
    curs.execute("""
        EXPLAIN PLAN FOR
        SELECT * FROM Kunden WHERE email = 'kunde_1000@example.com'
    """)
    # Fetch the plan results
    curs.execute("SELECT * FROM TABLE(DBMS_XPLAN.DISPLAY())")
    plan = curs.fetchall()
    print("Execution plan with index:")
    for row in plan:
        print(row)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Execution plan with index:
# ('Plan hash value: 2211476835',)
# (' ',)
# ('-------------------------------------------------------------------------------------------------',)
# ('| Id  | Operation                           | Name      | Rows  | Bytes | Cost (%CPU)| Time     |',)
# ('-------------------------------------------------------------------------------------------------',)
# ('|   0 | SELECT STATEMENT                    |           |     1 |    68 |     2   (0)| 00:00:01 |',)
# ('|   1 |  TABLE ACCESS BY INDEX ROWID BATCHED| KUNDEN    |     1 |    68 |     2   (0)| 00:00:01 |',)
# ('|*  2 |   INDEX RANGE SCAN                  | IDX_EMAIL |     1 |       |     1   (0)| 00:00:01 |',)
# ('-------------------------------------------------------------------------------------------------',)
# (' ',)
# ('Predicate Information (identified by operation id):',)
# ('---------------------------------------------------',)
# (' ',)
# ('   2 - access("EMAIL"=\'kunde_1000@example.com\')',)

# %% [markdown]
# # Close Connection

# %%
curs.close()
connection.close()
